# %% [markdown]
# # chapitre1
# - Les types
# - Les operateurs
# - Les listes
#
# 1. Structures conditionnelles
# 2. Les structures iteratives

# %%
print("hello world")
# Out:
# hello world

# %%
print("Salut je fais du python")
# Out:
# Salut je fais du python

# %%
phrase=input("entrer une phrase")
print(phrase)
# Out:
# lalla diaite
